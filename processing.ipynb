# %%
import pandas as pd
import numpy as np

# %%
# Read in the data
df = pd.read_csv('mobiles.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    264 non-null    object
#  1   price   264 non-null    object
#  2   rr      259 non-null    object
# dtypes: object(3)
# memory usage: 6.3+ KB
#                                           name    price  \
# 0                                  Cellecor E3   ₹1,176
# 1              realme C30 (Denim Black, 32 GB)   ₹5,749
# 2             realme C30 (Bamboo Green, 32 GB)   ₹5,749
# 3                realme C30 (Lake Blue, 32 GB)   ₹5,749
# 4              realme C30 (Denim Black, 32 GB)   ₹6,749
# ..                                         ...      ...
# 259         MOTOROLA e13 (Creamy White, 64 GB)   ₹6,999
# 260            MOTOROLA g31 (Baby Blue, 64 GB)   ₹9,499
# 261                               Nokia 105 ss   ₹1,475
# 262  REDMI Note 12 Pro 5G (Onyx Black, 128 GB)  ₹24,999
# ...

# %%
def clean_price_data(price):
    if isinstance(price, str):
        price = price.replace(',','').replace('₹','').strip()
    if price.isnumeric():
        return float(price)

# %%
def split_rr_data(rr):
    if isinstance(rr, str):
        rr = rr.split('&')
        return rr[0], rr[1]
    else:
        return np.nan, np.nan

# %%
df['cleaned_price']=df['price'].apply(clean_price_data)

# %%
df['ratings'], df['reviews'] = zip(*df['rr'].apply(split_rr_data)) # Unpacking the tuple

# %%
df
# Out:
#                                           name    price  \
# 0                                  Cellecor E3   ₹1,176
# 1              realme C30 (Denim Black, 32 GB)   ₹5,749
# 2             realme C30 (Bamboo Green, 32 GB)   ₹5,749
# 3                realme C30 (Lake Blue, 32 GB)   ₹5,749
# 4              realme C30 (Denim Black, 32 GB)   ₹6,749
# ..                                         ...      ...
# 259         MOTOROLA e13 (Creamy White, 64 GB)   ₹6,999
# 260            MOTOROLA g31 (Baby Blue, 64 GB)   ₹9,499
# 261                               Nokia 105 ss   ₹1,475
# 262  REDMI Note 12 Pro 5G (Onyx Black, 128 GB)  ₹24,999
# 263        realme 9 5G SE (Azure Glow, 128 GB)  ₹19,999
#
#                                  rr  cleaned_price          ratings  \
# 0            28 Ratings & 1 Reviews         1176.0      28 Ratings
# 1    94,043 Ratings & 4,998 Reviews         5749.0  94,043 Ratings
# 2    94,043 Ratings & 4,998 Reviews         5749.0  94,043 Ratings
# ...
