# %% [markdown]
# - math module
# - random module
# - os module
# - datetime module

# %% [markdown]
# - `import library`
# - `from library import func1, func2, func3`
# - `import library as lib` # alias
#
# ```
# from library import {
#     fun1, fun2, fun3
# }
# ```

# %%
import math

# %%
math.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
math.degrees(math.pi)
# Out:
# 180.0

# %%
from random import randint, random, choice

# %%
result = randint(1, 100)
print(f'I got {result}')
# Out:
# I got 90

# %%
random()
# Out:
# 0.5893751609467119

# %%
choice([12, 22, 33, 44, 55])
# Out:
# 22

# %%
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\ZAID\Documents\coding\2023 JAN PY MTWF 0200

# %%
base_dir = os.getcwd()

# %%
contents = os.listdir() # get the content of the current directory
print(contents)
# Out:
# ['.git', 'basics', 'dice_simulator.py', 'dict.ipynb', 'libraries.ipynb', 'list_1.ipynb', 'questions.txt', 'tuples.ipynb']

# %%
programs = os.listdir('C:\Program Files')
print(programs)
# Out:
# ['Adobe', 'Android', 'Audacity', 'Blackmagic Design', 'Blender Foundation', 'Bonjour', 'Common Files', 'Cyberduck', 'desktop.ini', 'DIFX', 'dotnet', 'Electronic Arts', 'Epic Games', 'Everything', 'FFmpeg for Audacity', 'Fing', 'Git', 'Google', 'Internet Explorer', 'JetBrains', 'Lame For Audacity', 'Lenovo', 'MAGIX', 'Microsoft Office', 'Microsoft Office 15', 'Microsoft OneDrive', 'Microsoft Update Health Tools', 'Microsoft VS Code', 'ModifiableWindowsApps', 'MSBuild', 'MySQL', 'Nefarius Software Solutions', 'NitroShare', 'nodejs', 'Npcap', 'NVIDIA Corporation', 'paint.net', 'Pentablet', 'PowerToys', 'PRISMLiveStudio', 'RapidMiner', 'Reference Assemblies', 'Riot Vanguard', 'Rockstar Games', 'Sony', 'Soundly', 'Uninstall Information', 'Unity Hub', 'VLC', 'Windows Defender', 'Windows Mail', 'Windows NT', 'Windows Photo Viewer', 'Windows Sidebar', 'WindowsApps', 'WindowsPowerShell', 'Wondershare']

# %%
for path, folders, files in os.walk('C:\Program Files\Microsoft VS Code'):
    print(f'{folders} | {files}')
# Out:
# ['bin', 'locales', 'policies', 'resources', 'tools'] | ['chrome_100_percent.pak', 'chrome_200_percent.pak', 'Code.exe', 'Code.VisualElementsManifest.xml', 'd3dcompiler_47.dll', 'ffmpeg.dll', 'icudtl.dat', 'libEGL.dll', 'libGLESv2.dll', 'resources.pak', 'snapshot_blob.bin', 'unins000.dat', 'unins000.exe', 'unins000.msg', 'v8_context_snapshot.bin', 'vk_swiftshader.dll', 'vk_swiftshader_icd.json', 'vulkan-1.dll']
# [] | ['code', 'code-tunnel.exe', 'code.cmd']
# [] | ['af.pak', 'am.pak', 'ar.pak', 'bg.pak', 'bn.pak', 'ca.pak', 'cs.pak', 'da.pak', 'de.pak', 'el.pak', 'en-GB.pak', 'en-US.pak', 'es-419.pak', 'es.pak', 'et.pak', 'fa.pak', 'fi.pak', 'fil.pak', 'fr.pak', 'gu.pak', 'he.pak', 'hi.pak', 'hr.pak', 'hu.pak', 'id.pak', 'it.pak', 'ja.pak', 'kn.pak', 'ko.pak', 'lt.pak', 'lv.pak', 'ml.pak', 'mr.pak', 'ms.pak', 'nb.pak', 'nl.pak', 'pl.pak', 'pt-BR.pak', 'pt-PT.pak', 'ro.pak', 'ru.pak', 'sk.pak', 'sl.pak', 'sr.pak', 'sv.pak', 'sw.pak', 'ta.pak', 'te.pak', 'th.pak', 'tr.pak', 'uk.pak', 'ur.pak', 'vi.pak', 'zh-CN.pak', 'zh-TW.pak']
# ['cs-cz', 'de-de', 'en-us', 'es-es', 'fr-fr', 'it-it', 'ja-jp', 'ko-kr', 'pl-pl', 'pt-br', 'ru-ru', 'tr-tr', 'zh-cn', 'zh-tw'] | ['VSCode.admx']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# [] | ['VSCode.adml']
# ['app'] | []
# ['extensions', 'licenses', 'node_modules.asar.unpacked', 'out', 'resources'] | ['LICENSE.rtf', 'LICENSES.chromium.html', 'node_modules.asar', 'package.json', 'product.json', 'telemetry-core.json', 'telemetry-extensions.json', 'ThirdPartyNotices.txt']
# ['bat', 'clojure', 'coffeescript', 'configuration-editing', 'cpp', 'csharp', 'css', 'css-language-features', 'dart', 'debug-auto-launch', 'debug-server-ready', 'diff', 'docker', 'emmet', 'extension-editing', 'fsharp', 'git', 'git-base', 'github', 'github-authentication', 'go', 'groovy', 'grunt', 'gulp', 'handlebars', 'hlsl', 'html', 'html-language-features', 'ini', 'ipynb', 'jake', 'java', 'javascript', 'json', 'json-language-features', 'julia', 'latex', 'less', 'log', 'lua', 'make', 'markdown-basics', 'markdown-language-features', 'markdown-math', 'media-preview', 'merge-conflict', 'microsoft-authentication', 'ms-vscode-remote.remote-wsl-recommender', 'ms-vscode.js-debug', 'ms-vscode.js-debug-companion', 'ms-vscode.vscode-js-profile-table', 'node_modules', 'notebook-renderers', 'npm', 'objective-c', 'perl', 'php', 'php-language-features', 'powershell', 'pug', 'python', 'r', 'razor', 'references-view', 'restructuredtext', 'ruby', 'rust', 'scss', 'search-result', 'shaderlab', 'shellscript', 'simple-browser', 'sql', 'swift', 'theme-abyss', 'theme-defaults', 'theme-kimbie-dark', 'theme-monokai', 'theme-monokai-dimmed', 'theme-quietlight', 'theme-red', 'theme-seti', 'theme-solarized-dark', 'theme-solarized-light', 'theme-tomorrow-night-blue', 'typescript-basics', 'typescript-language-features', 'vb', 'xml', 'yaml'] | []
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['batchfile.code-snippets']
# [] | ['batchfile.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['clojure.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['coffeescript.code-snippets']
# [] | ['coffeescript.tmLanguage.json']
# ['dist', 'images', 'schemas'] | ['package.json', 'package.nls.json']
# [] | ['configurationEditingMain.js', 'configurationEditingMain.js.LICENSE.txt']
# [] | ['icon.png']
# [] | ['attachContainer.schema.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['c.code-snippets', 'cpp.code-snippets']
# [] | ['c.tmLanguage.json', 'cpp.embedded.macro.tmLanguage.json', 'cpp.tmLanguage.json', 'cuda-cpp.tmLanguage.json', 'platform.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['csharp.code-snippets']
# [] | ['csharp.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['css.tmLanguage.json']
# ['client', 'icons', 'schemas', 'server'] | ['package.json', 'package.nls.json', 'README.md']
# ['dist'] | []
# ['node'] | []
# [] | ['cssClientMain.js']
# [] | ['css.png']
# [] | ['package.schema.json']
# ['dist'] | ['package.json']
# ['node'] | []
# [] | ['cssServerMain.js']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['dart.tmLanguage.json']
# ['.vscode', 'dist', 'media'] | ['package.json', 'package.nls.json']
# [] | ['launch.json']
# [] | ['extension.js']
# [] | ['icon.png']
# ['dist', 'media'] | ['package.json', 'package.nls.json']
# [] | ['extension.js']
# [] | ['icon.png']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['diff.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['docker.tmLanguage.json']
# ['dist', 'images'] | ['package.json', 'package.nls.json', 'README.md']
# ['node'] | []
# [] | ['emmetNodeMain.js']
# [] | ['icon.png']
# ['dist', 'images'] | ['package.json', 'package.nls.json']
# [] | ['extensionEditingMain.js']
# [] | ['icon.png']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['fsharp.code-snippets']
# [] | ['fsharp.tmLanguage.json']
# ['dist', 'resources'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['askpass-empty.sh', 'askpass-main.js', 'askpass.sh', 'git-editor-empty.sh', 'git-editor-main.js', 'git-editor.sh', 'main.js', 'main.js.LICENSE.txt', 'ssh-askpass-empty.sh', 'ssh-askpass.sh']
# ['icons'] | ['emojis.json']
# ['dark', 'light'] | ['git.png']
# [] | ['status-added.svg', 'status-conflict.svg', 'status-copied.svg', 'status-deleted.svg', 'status-ignored.svg', 'status-modified.svg', 'status-renamed.svg', 'status-untracked.svg']
# [] | ['status-added.svg', 'status-conflict.svg', 'status-copied.svg', 'status-deleted.svg', 'status-ignored.svg', 'status-modified.svg', 'status-renamed.svg', 'status-untracked.svg']
# ['dist', 'languages', 'resources', 'syntaxes'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js']
# [] | ['git-commit.language-configuration.json', 'git-rebase.language-configuration.json', 'ignore.language-configuration.json']
# ['icons'] | []
# [] | ['git.png']
# [] | ['git-commit.tmLanguage.json', 'git-rebase.tmLanguage.json', 'ignore.tmLanguage.json']
# ['dist', 'images', 'testWorkspace'] | ['markdown.css', 'package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js', 'extension.js.LICENSE.txt']
# [] | ['icon.png']
# ['docs', 'PULL_REQUEST_TEMPLATE'] | ['PULL_REQUEST_TEMPLATE.md', 'some-markdown.md', 'x.txt']
# ['PULL_REQUEST_TEMPLATE'] | ['PULL_REQUEST_TEMPLATE.md']
# [] | ['a.md', 'b.md', 'x.txt']
# [] | ['a.md', 'b.md', 'x.txt']
# ['dist', 'images', 'media'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js', 'extension.js.LICENSE.txt']
# [] | ['icon.png']
# [] | ['auth.css', 'favicon.ico', 'icon.png', 'index.html']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['go.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['groovy.code-snippets']
# [] | ['groovy.tmLanguage.json']
# ['dist', 'images'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['main.js']
# [] | ['grunt.png']
# ['dist', 'images'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['main.js']
# [] | ['gulp.png']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['Handlebars.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['hlsl.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['html.code-snippets']
# [] | ['html-derivative.tmLanguage.json', 'html.tmLanguage.json']
# ['client', 'icons', 'schemas', 'server'] | ['package.json', 'package.nls.json', 'README.md']
# ['dist'] | []
# ['node'] | []
# [] | ['htmlClientMain.js', 'htmlClientMain.js.LICENSE.txt']
# [] | ['html.png']
# [] | ['package.schema.json']
# ['dist', 'lib'] | ['package.json']
# ['node'] | []
# [] | ['htmlServerMain.js']
# [] | ['jquery.d.ts']
# ['syntaxes'] | ['ini.language-configuration.json', 'package.json', 'package.nls.json', 'properties.language-configuration.json']
# [] | ['ini.tmLanguage.json']
# ['dist', 'notebook-out'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['ipynbMain.js']
# [] | ['cellAttachmentRenderer.js']
# ['dist', 'images'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['main.js']
# [] | ['cowboy_hat.png']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['java.code-snippets']
# [] | ['java.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['javascript-language-configuration.json', 'package.json', 'package.nls.json', 'tags-language-configuration.json']
# [] | ['javascript.code-snippets']
# [] | ['JavaScript.tmLanguage.json', 'JavaScriptReact.tmLanguage.json', 'Regular Expressions (JavaScript).tmLanguage']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['JSON.tmLanguage.json', 'JSONC.tmLanguage.json']
# ['client', 'icons', 'server'] | ['package.json', 'package.nls.json', 'README.md']
# ['dist'] | []
# ['node'] | []
# [] | ['jsonClientMain.js', 'jsonClientMain.js.LICENSE.txt']
# [] | ['json.png']
# ['dist'] | ['package.json']
# ['node'] | []
# [] | ['jsonServerMain.js']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['julia.tmLanguage.json']
# ['syntaxes'] | ['cpp-bailout-license.txt', 'latex-cpp-embedded-language-configuration.json', 'latex-language-configuration.json', 'markdown-latex-combined-language-configuration.json', 'markdown-latex-combined-license.txt', 'package.json', 'package.nls.json']
# [] | ['Bibtex.tmLanguage.json', 'cpp-grammar-bailout.tmLanguage.json', 'LaTeX.tmLanguage.json', 'markdown-latex-combined.tmLanguage.json', 'TeX.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['less.tmLanguage.json']
# ['syntaxes'] | ['package.json', 'package.nls.json']
# [] | ['log.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['lua.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['make.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['markdown.code-snippets']
# [] | ['markdown.tmLanguage.json']
# ['dist', 'media', 'notebook-out', 'schemas', 'server'] | ['icon.png', 'package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js', 'extension.js.LICENSE.txt']
# [] | ['highlight.css', 'index.js', 'markdown.css', 'pre.js', 'preview-dark.svg', 'preview-light.svg']
# [] | ['index.js']
# [] | ['package.schema.json']
# ['dist'] | ['package.json', 'README.md']
# ['node'] | []
# [] | ['workerMain.js']
# ['dist', 'notebook-out', 'preview-styles', 'syntaxes'] | ['icon.png', 'package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js']
# ['fonts'] | ['katex.js', 'katex.min.css']
# [] | ['KaTeX_AMS-Regular.woff2', 'KaTeX_Caligraphic-Bold.woff2', 'KaTeX_Caligraphic-Regular.woff2', 'KaTeX_Fraktur-Bold.woff2', 'KaTeX_Fraktur-Regular.woff2', 'KaTeX_Main-Bold.woff2', 'KaTeX_Main-BoldItalic.woff2', 'KaTeX_Main-Italic.woff2', 'KaTeX_Main-Regular.woff2', 'KaTeX_Math-BoldItalic.woff2', 'KaTeX_Math-Italic.woff2', 'KaTeX_SansSerif-Bold.woff2', 'KaTeX_SansSerif-Italic.woff2', 'KaTeX_SansSerif-Regular.woff2', 'KaTeX_Script-Regular.woff2', 'KaTeX_Size1-Regular.woff2', 'KaTeX_Size2-Regular.woff2', 'KaTeX_Size3-Regular.woff2', 'KaTeX_Size4-Regular.woff2', 'KaTeX_Typewriter-Regular.woff2']
# [] | ['index.css']
# [] | ['md-math-block.tmLanguage.json', 'md-math-inline.tmLanguage.json', 'md-math.tmLanguage.json']
# ['dist', 'media'] | ['icon.png', 'package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js']
# [] | ['audioPreview.css', 'audioPreview.js', 'imagePreview.css', 'imagePreview.js', 'loading-dark.svg', 'loading-hc.svg', 'loading.svg', 'videoPreview.css', 'videoPreview.js']
# ['dist', 'media'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['mergeConflictMain.js', 'mergeConflictMain.js.LICENSE.txt']
# [] | ['icon.png']
# ['dist', 'media'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js', 'extension.js.LICENSE.txt']
# [] | ['auth.css', 'favicon.ico', 'icon.png', 'index.html']
# ['dist', 'resources'] | ['CHANGELOG.md', 'LICENSE.txt', 'package.json', 'package.nls.cs.json', 'package.nls.de.json', 'package.nls.es.json', 'package.nls.fr.json', 'package.nls.it.json', 'package.nls.ja.json', 'package.nls.json', 'package.nls.ko.json', 'package.nls.pl.json', 'package.nls.pt-br.json', 'package.nls.qps-ploc.json', 'package.nls.ru.json', 'package.nls.tr.json', 'package.nls.zh-cn.json', 'package.nls.zh-tw.json', 'README.md', 'SECURITY.md', 'telemetry.json', 'ThirdPartyNotices.txt']
# [] | ['extension.js', 'extension.js.LICENSE.txt', 'nls.metadata.header.json', 'nls.metadata.json']
# [] | ['remote-wsl.png']
# ['l10n-extract', 'resources', 'src'] | ['LICENSE.txt', 'package.json', 'package.nls.json', 'README.md', 'ThirdPartyNotices.txt']
# [] | ['bundle.l10n.json']
# ['dark', 'light', 'readme'] | ['logo.png', 'logo.svg']
# [] | ['configure.svg', 'connect.svg', 'disconnect.svg', 'node.svg', 'open-file.svg', 'page.svg', 'pause.svg', 'restart.svg', 'resume.svg', 'service-worker.svg', 'stop-profiling.svg', 'stop.svg', 'worker.svg']
# [] | ['configure.svg', 'connect.svg', 'disconnect.svg', 'node.svg', 'open-file.svg', 'page.svg', 'pause.svg', 'restart.svg', 'resume.svg', 'service-worker.svg', 'stop.svg', 'worker.svg']
# [] | ['auto-attach.png', 'flame-chart.png', 'instrumentation-breakpoints.png', 'instrumentation-breakpoints2.png', 'link-debugging.gif', 'logo-with-text.png', 'npm-code-lens.png', 'repl-improvements.png', 'returnvalue.png', 'top-level-await.png', 'web-worker.png', 'webview2.png']
# [] | ['25b0f220a897d7433728f6f34169bdbf.node', 'bootloader.bundle.js', 'bootloader.bundle.js.LICENSE.txt', 'chromehash_bg.wasm', 'diagnosticTool.bundle.js', 'extension.js', 'extension.js.LICENSE.txt', 'hash.bundle.js', 'mappings.wasm', 'terminateProcess.sh', 'watchdog.bundle.js', 'watchdog.bundle.js.LICENSE.txt']
# ['out', 'resources'] | ['ci.yml', 'LICENSE.txt', 'package.json', 'README.md', 'SECURITY.md', 'ThirdPartyNotices.txt']
# [] | ['extension.js']
# [] | ['logo.png']
# ['out', 'resources'] | ['ci.yml', 'package.json', 'README.md', 'ThirdPartyNotices.txt', 'tsconfig.browser.json', 'webpack.cpu-client.js', 'webpack.extension.js', 'webpack.heap-client.js']
# [] | ['cpu-client.bundle.js', 'extension.js', 'extension.web.js', 'heap-client.bundle.js']
# [] | ['icon.png']
# ['typescript'] | []
# ['lib'] | ['package.json']
# ['cs', 'de', 'es', 'fr', 'it', 'ja', 'ko', 'pl', 'pt-br', 'ru', 'tr', 'zh-cn', 'zh-tw'] | ['cancellationToken.js', 'dynamicImportCompat.js', 'lib.d.ts', 'lib.dom.d.ts', 'lib.dom.iterable.d.ts', 'lib.es2015.collection.d.ts', 'lib.es2015.core.d.ts', 'lib.es2015.d.ts', 'lib.es2015.generator.d.ts', 'lib.es2015.iterable.d.ts', 'lib.es2015.promise.d.ts', 'lib.es2015.proxy.d.ts', 'lib.es2015.reflect.d.ts', 'lib.es2015.symbol.d.ts', 'lib.es2015.symbol.wellknown.d.ts', 'lib.es2016.array.include.d.ts', 'lib.es2016.d.ts', 'lib.es2016.full.d.ts', 'lib.es2017.d.ts', 'lib.es2017.full.d.ts', 'lib.es2017.intl.d.ts', 'lib.es2017.object.d.ts', 'lib.es2017.sharedmemory.d.ts', 'lib.es2017.string.d.ts', 'lib.es2017.typedarrays.d.ts', 'lib.es2018.asyncgenerator.d.ts', 'lib.es2018.asynciterable.d.ts', 'lib.es2018.d.ts', 'lib.es2018.full.d.ts', 'lib.es2018.intl.d.ts', 'lib.es2018.promise.d.ts', 'lib.es2018.regexp.d.ts', 'lib.es2019.array.d.ts', 'lib.es2019.d.ts', 'lib.es2019.full.d.ts', 'lib.es2019.intl.d.ts', 'lib.es2019.object.d.ts', 'lib.es2019.string.d.ts', 'lib.es2019.symbol.d.ts', 'lib.es2020.bigint.d.ts', 'lib.es2020.d.ts', 'lib.es2020.date.d.ts', 'lib.es2020.full.d.ts', 'lib.es2020.intl.d.ts', 'lib.es2020.number.d.ts', 'lib.es2020.promise.d.ts', 'lib.es2020.sharedmemory.d.ts', 'lib.es2020.string.d.ts', 'lib.es2020.symbol.wellknown.d.ts', 'lib.es2021.d.ts', 'lib.es2021.full.d.ts', 'lib.es2021.intl.d.ts', 'lib.es2021.promise.d.ts', 'lib.es2021.string.d.ts', 'lib.es2021.weakref.d.ts', 'lib.es2022.array.d.ts', 'lib.es2022.d.ts', 'lib.es2022.error.d.ts', 'lib.es2022.full.d.ts', 'lib.es2022.intl.d.ts', 'lib.es2022.object.d.ts', 'lib.es2022.sharedmemory.d.ts', 'lib.es2022.string.d.ts', 'lib.es5.d.ts', 'lib.es6.d.ts', 'lib.esnext.d.ts', 'lib.esnext.full.d.ts', 'lib.esnext.intl.d.ts', 'lib.esnext.promise.d.ts', 'lib.esnext.string.d.ts', 'lib.esnext.weakref.d.ts', 'lib.scripthost.d.ts', 'lib.webworker.d.ts', 'lib.webworker.importscripts.d.ts', 'lib.webworker.iterable.d.ts', 'tsserver.js', 'typescript.js', 'typesMap.json', 'typingsInstaller.js', 'watchGuard.js']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# [] | ['diagnosticMessages.generated.json']
# ['renderer-out'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['index.js']
# ['dist', 'images'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['npmMain.js', 'npmMain.js.LICENSE.txt']
# [] | ['code.svg', 'npm_icon.png']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['objective-c++.tmLanguage.json', 'objective-c.tmLanguage.json']
# ['syntaxes'] | ['package.json', 'package.nls.json', 'perl.language-configuration.json', 'perl6.language-configuration.json']
# [] | ['perl.tmLanguage.json', 'perl6.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['php.code-snippets']
# [] | ['html.tmLanguage.json', 'php.tmLanguage.json']
# ['dist', 'icons'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['phpMain.js']
# [] | ['logo.png']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['powershell.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['pug.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['MagicPython.tmLanguage.json', 'MagicRegExp.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['r.tmLanguage.json']
# ['build', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['update-grammar.mjs']
# [] | ['cshtml.tmLanguage.json']
# ['dist', 'media'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js']
# [] | ['demo.png', 'icon.png']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['rst.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['ruby.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['rust.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['sassdoc.tmLanguage.json', 'scss.tmLanguage.json']
# ['dist', 'images', 'syntaxes'] | ['package.json', 'package.nls.json', 'README.md']
# ['media'] | ['extension.js']
# [] | ['refresh-dark.svg', 'refresh-light.svg']
# [] | ['icon.png']
# [] | ['searchResult.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['shaderlab.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['shell-unix-bash.tmLanguage.json']
# ['dist', 'media'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js']
# [] | ['codicon.css', 'codicon.ttf', 'icon.png', 'index.js', 'main.css', 'preview-dark.svg', 'preview-light.svg']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['sql.tmLanguage.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'LICENSE.md', 'package.json', 'package.nls.json']
# [] | ['swift.code-snippets']
# [] | ['swift.tmLanguage.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['abyss-color-theme.json']
# ['fileicons', 'themes'] | ['package.json', 'package.nls.json']
# ['images'] | ['vs_minimal-icon-theme.json']
# [] | ['document-dark.svg', 'document-light.svg', 'folder-dark.svg', 'folder-light.svg', 'folder-open-dark.svg', 'folder-open-light.svg', 'root-folder-dark.svg', 'root-folder-light.svg', 'root-folder-open-dark.svg', 'root-folder-open-light.svg']
# [] | ['dark_plus.json', 'dark_plus_experimental.json', 'dark_vs.json', 'hc_black.json', 'hc_light.json', 'light_plus.json', 'light_plus_experimental.json', 'light_vs.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['kimbie-dark-color-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['monokai-color-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['dimmed-monokai-color-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['quietlight-color-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['Red-color-theme.json']
# ['icons'] | ['package.json', 'package.nls.json', 'README.md', 'ThirdPartyNotices.txt']
# [] | ['seti-circular-128x128.png', 'seti.woff', 'vs-seti-icon-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['solarized-dark-color-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['solarized-light-color-theme.json']
# ['themes'] | ['package.json', 'package.nls.json']
# [] | ['tomorrow-night-blue-color-theme.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['typescript.code-snippets']
# [] | ['jsdoc.js.injection.tmLanguage.json', 'jsdoc.ts.injection.tmLanguage.json', 'TypeScript.tmLanguage.json', 'TypeScriptReact.tmLanguage.json']
# ['dist', 'media', 'resources', 'schemas'] | ['package.json', 'package.nls.json', 'README.md']
# [] | ['extension.js', 'extension.js.LICENSE.txt']
# [] | ['icon.png', 'nodejsWalkthroughIcon.png']
# ['walkthroughs'] | []
# [] | ['create-a-js-file.svg', 'debug-and-run.svg', 'install-node-js.svg', 'learn-more.svg']
# [] | ['jsconfig.schema.json', 'package.schema.json', 'tsconfig.schema.json']
# ['snippets', 'syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['vb.code-snippets']
# [] | ['asp-vb-net.tmlanguage.json']
# ['syntaxes'] | ['package.json', 'package.nls.json', 'xml.language-configuration.json', 'xsl.language-configuration.json']
# [] | ['xml.tmLanguage.json', 'xsl.tmLanguage.json']
# ['syntaxes'] | ['language-configuration.json', 'package.json', 'package.nls.json']
# [] | ['yaml.tmLanguage.json']
# [] | ['LICENSE-bul.rtf', 'LICENSE-chs.rtf', 'LICENSE-cht.rtf', 'LICENSE-deu.rtf', 'LICENSE-esp.rtf', 'LICENSE-fra.rtf', 'LICENSE-hun.rtf', 'LICENSE-ita.rtf', 'LICENSE-jpn.rtf', 'LICENSE-kor.rtf', 'LICENSE-ptb.rtf', 'LICENSE-rus.rtf', 'LICENSE-trk.rtf']
# ['@parcel', '@vscode', 'keytar', 'native-is-elevated', 'native-keymap', 'native-watchdog', 'node-pty', 'node-vsce-sign', 'spdlog', 'vscode-encrypt', 'vscode-oniguruma', 'vscode-windows-ca-certs', 'vsda', 'windows-foreground-love', 'windows-mutex', 'windows-process-tree'] | []
# ['watcher'] | []
# ['build'] | []
# ['Release'] | []
# [] | ['watcher.node']
# ['policy-watcher', 'ripgrep', 'sqlite3', 'windows-registry'] | []
# ['build'] | []
# ['Release'] | []
# [] | ['vscode-policy-watcher.node']
# ['bin'] | []
# [] | ['rg.exe']
# ['build'] | []
# ['Release'] | []
# [] | ['vscode-sqlite3.node']
# ['build'] | []
# ['Release'] | []
# [] | ['winregistry.node']
# ['build'] | []
# ['Release'] | []
# [] | ['keytar.node']
# ['build'] | []
# ['Release'] | []
# [] | ['iselevated.node']
# ['build'] | []
# ['Release'] | []
# [] | ['keymapping.node']
# ['build'] | []
# ['Release'] | []
# [] | ['watchdog.node']
# ['build', 'lib'] | []
# ['Release'] | []
# [] | ['conpty.node', 'conpty_console_list.node', 'pty.node', 'winpty-agent.exe', 'winpty.dll']
# ['shared', 'worker'] | []
# [] | ['conout.js']
# [] | ['conoutSocketWorker.js']
# ['bin'] | []
# [] | ['vsce-sign.exe']
# ['build'] | []
# ['Release'] | []
# [] | ['spdlog.node']
# ['build'] | []
# ['Release'] | []
# [] | ['vscode-encrypt-native.node']
# ['release'] | []
# [] | ['onig.wasm']
# ['build'] | []
# ['Release'] | []
# [] | ['crypt32.node']
# ['build'] | []
# ['Release'] | []
# [] | ['vsda.node']
# ['build'] | []
# ['Release'] | []
# [] | ['foreground_love.node']
# ['build'] | []
# ['Release'] | []
# [] | ['CreateMutex.node']
# ['build'] | []
# ['Release'] | []
# [] | ['windows_process_tree.node']
# ['vs', 'vscode-dts'] | ['bootstrap-amd.js', 'bootstrap-fork.js', 'bootstrap-node.js', 'bootstrap-window.js', 'bootstrap.js', 'cli.js', 'main.js', 'nls.metadata.json']
# ['base', 'code', 'editor', 'platform', 'workbench'] | ['loader.js']
# ['browser', 'common', 'node', 'parts', 'worker'] | []
# ['ui'] | []
# ['codicons'] | []
# ['codicon'] | []
# [] | ['codicon-modifiers.css', 'codicon.css', 'codicon.ttf']
# ['worker'] | ['performance.js']
# [] | ['simpleWorker.js', 'simpleWorker.nls.js']
# [] | ['cpuUsage.sh', 'ps.sh', 'terminateProcess.sh']
# ['sandbox'] | []
# ['electron-browser'] | []
# [] | ['preload.js']
# [] | ['workerMain.js']
# ['electron-main', 'electron-sandbox', 'node'] | []
# [] | ['main.js', 'main.nls.js']
# ['issue', 'processExplorer', 'workbench'] | []
# [] | ['issueReporter-dev.html', 'issueReporter.html', 'issueReporter.js', 'issueReporterMain.css', 'issueReporterMain.js', 'issueReporterMain.nls.js']
# [] | ['processExplorer-dev.html', 'processExplorer.html', 'processExplorer.js', 'processExplorerMain.css', 'processExplorerMain.js', 'processExplorerMain.nls.js']
# [] | ['workbench-dev.html', 'workbench.html', 'workbench.js']
# ['sharedProcess'] | ['cli.js', 'cli.nls.js', 'cliProcessMain.js', 'cliProcessMain.nls.js']
# [] | ['sharedProcess-dev.html', 'sharedProcess.html', 'sharedProcess.js', 'sharedProcessMain.js', 'sharedProcessMain.nls.js']
# ['common'] | []
# ['services'] | []
# [] | ['editorSimpleWorker.nls.js']
# ['audioCues', 'files', 'profiling', 'sharedProcess', 'terminal'] | []
# ['browser'] | []
# ['media'] | []
# [] | ['break.mp3', 'diffLineDeleted.mp3', 'diffLineInserted.mp3', 'diffLineModified.mp3', 'error.mp3', 'foldedAreas.mp3', 'quickFixes.mp3', 'taskCompleted.mp3', 'taskFailed.mp3', 'terminalBell.mp3', 'warning.mp3']
# ['node'] | []
# ['watcher'] | []
# [] | ['watcherMain.js', 'watcherMain.nls.js']
# ['electron-sandbox'] | []
# [] | ['profileAnalysisWorker.js']
# ['electron-browser'] | []
# [] | ['sharedProcessWorkerMain.js', 'sharedProcessWorkerMain.nls.js']
# ['node'] | []
# [] | ['ptyHostMain.js', 'ptyHostMain.nls.js']
# ['api', 'browser', 'contrib', 'services'] | ['workbench.desktop.main.css', 'workbench.desktop.main.js', 'workbench.desktop.main.nls.js']
# ['node', 'worker'] | []
# [] | ['extensionHostProcess.js', 'extensionHostProcess.nls.js']
# [] | ['extensionHostWorker.js', 'extensionHostWorker.nls.js']
# ['parts'] | []
# ['editor'] | []
# ['media'] | []
# [] | ['back-tb.png', 'forward-tb.png']
# ['debug', 'extensions', 'externalTerminal', 'interactive', 'notebook', 'output', 'terminal', 'webview', 'welcomeGettingStarted', 'welcomeOverlay'] | []
# ['browser', 'node'] | []
# ['media'] | []
# [] | ['continue-tb.png', 'pause-tb.png', 'restart-tb.png', 'run-with-debugging-tb.png', 'stepinto-tb.png', 'stepout-tb.png', 'stepover-tb.png', 'stop-tb.png']
# [] | ['telemetryApp.js', 'telemetryApp.nls.js']
# ['browser'] | []
# ['media'] | []
# [] | ['language-icon.svg', 'theme-icon.png']
# ['node'] | []
# [] | ['iTermHelper.scpt', 'TerminalHelper.scpt']
# ['browser'] | []
# ['docs'] | []
# [] | ['interactive.editor.drawio.svg', 'interactive.eh.drawio.svg']
# ['browser', 'common'] | []
# ['docs'] | []
# [] | ['cell-resize-above-viewport.drawio.svg', 'hybrid-find.drawio.svg', 'viewport-rendering.drawio.svg']
# ['services'] | []
# [] | ['notebookSimpleWorker.js']
# ['common'] | []
# [] | ['outputLinkComputer.js']
# ['browser'] | []
# ['media'] | []
# [] | ['shellIntegration-bash.sh', 'shellIntegration-env.zsh', 'shellIntegration-login.zsh', 'shellIntegration-profile.zsh', 'shellIntegration-rc.zsh', 'shellIntegration.fish', 'shellIntegration.ps1']
# ['browser'] | []
# ['pre'] | []
# [] | ['fake.html', 'index-no-csp.html', 'index.html', 'service-worker.js']
# ['common'] | []
# ['media'] | []
# ['notebookThemes'] | ['commandPalette.svg', 'dark-hc.png', 'dark.png', 'debug.svg', 'extensions-web.svg', 'extensions.svg', 'git.svg', 'interactivePlayground.svg', 'languages.svg', 'learn.svg', 'light-hc.png', 'light.png', 'menuBar.svg', 'openFolder.svg', 'runTask.svg', 'search.svg', 'settings.svg', 'settingsSync.svg', 'shortcuts.svg', 'sideBySide.svg', 'terminal.svg', 'workspaceTrust.svg']
# [] | ['colab.png', 'default.png', 'jupyter.png']
# ['browser'] | []
# ['media'] | []
# [] | ['commandpalette-dark.svg', 'commandpalette.svg']
# ['extensionManagement', 'extensions', 'languageDetection', 'search', 'textMate'] | []
# ['common'] | []
# ['media'] | []
# [] | ['defaultIcon.png']
# ['worker'] | []
# [] | ['webWorkerExtensionHostIframe.html']
# ['browser'] | []
# [] | ['languageDetectionSimpleWorker.js']
# ['worker'] | []
# [] | ['localFileSearch.js']
# ['browser'] | []
# ['worker'] | []
# [] | ['textMate.worker.js']
# [] | ['vscode.d.ts']
# ['win32'] | []
# [] | ['bower.ico', 'c.ico', 'code_150x150.png', 'code_70x70.png', 'config.ico', 'cpp.ico', 'csharp.ico', 'css.ico', 'default.ico', 'go.ico', 'html.ico', 'jade.ico', 'java.ico', 'javascript.ico', 'json.ico', 'less.ico', 'markdown.ico', 'php.ico', 'powershell.ico', 'python.ico', 'react.ico', 'ruby.ico', 'sass.ico', 'shell.ico', 'sql.ico', 'typescript.ico', 'vue.ico', 'xml.ico', 'yaml.ico']
# [] | ['inno_updater.exe', 'vcruntime140.dll']

# %%
os.path.exists('C:\Program Files\Microsoft VS Code')
# Out:
# True
